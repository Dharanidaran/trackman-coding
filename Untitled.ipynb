# %%
from graphviz import Digraph

# %%
dot = Digraph(comment='The Round Table')

# %%
dot

# %%
dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

# %%
dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

# %%
print(dot.source)
# Out:
# // The Round Table
# digraph {
# 	A [label="King Arthur"]
# 	B [label="Sir Bedevere the Wise"]
# 	L [label="Sir Lancelot the Brave"]
# 	A -> B
# 	A -> L
# 	B -> L [constraint=false]
# }

# %%
from graphviz import Graph

g = Graph('G', filename='process.gv')

g.edge('report.delivered_new_pk', 'broadcast.delivered_games')
g.edge('report.delivered_exceptions_hist', 'report.delivered_new_pk')
g.edge('report.delivered_exceptions_hist', 'base.games')
g.edge('report.exp_access_rules_hist', 'rundown.access_rules_end')
g.edge('report.exp_access_rules_hist', 'broadcast.priority_lists')
g.edge('report.delivered_exceptions_hist', 'report.exp_access_rules_hist')



g.view()
# Out:
# 'process.gv.pdf'
